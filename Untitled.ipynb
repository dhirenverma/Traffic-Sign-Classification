# %%
import tensorflow as tf
import os
import pickle
import csv
import numpy as np
import scipy as sp
import pandas as pd
import sklearn as sk
from sklearn.utils import shuffle
import random
import cv2
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from tensorflow.contrib.layers import flatten

import glob
from scipy import misc
from PIL import Image

a = np.array([[ 0.24879643,  0.07032244,  0.12641572,  0.34763842,  0.07893497,
         0.12789202],
       [ 0.28086119,  0.27569815,  0.08594638,  0.0178669 ,  0.18063401,
         0.15899337],
       [ 0.26076848,  0.23664738,  0.08020603,  0.07001922,  0.1134371 ,
         0.23892179],
       [ 0.11943333,  0.29198961,  0.02605103,  0.26234032,  0.1351348 ,
         0.16505091],
       [ 0.09561176,  0.34396535,  0.0643941 ,  0.16240774,  0.24206137,
         0.09155967]])

# %%
a
# Out:
# array([[ 0.24879643,  0.07032244,  0.12641572,  0.34763842,  0.07893497,
#          0.12789202],
#        [ 0.28086119,  0.27569815,  0.08594638,  0.0178669 ,  0.18063401,
#          0.15899337],
#        [ 0.26076848,  0.23664738,  0.08020603,  0.07001922,  0.1134371 ,
#          0.23892179],
#        [ 0.11943333,  0.29198961,  0.02605103,  0.26234032,  0.1351348 ,
#          0.16505091],
#        [ 0.09561176,  0.34396535,  0.0643941 ,  0.16240774,  0.24206137,
#          0.09155967]])

# %%
with tf.Session() as sess:
    k = sess.run(tf.nn.top_k(a, 3))

# %%
print (k,type(k))
# Out:
# TopKV2(values=array([[ 0.34763842,  0.24879643,  0.12789202],
#        [ 0.28086119,  0.27569815,  0.18063401],
#        [ 0.26076848,  0.23892179,  0.23664738],
#        [ 0.29198961,  0.26234032,  0.16505091],
#        [ 0.34396535,  0.24206137,  0.16240774]]), indices=array([[3, 0, 5],
#        [0, 1, 4],
#        [0, 5, 1],
#        [1, 3, 5],
#        [1, 4, 3]])) <class 'tensorflow.python.ops.gen_nn_ops.TopKV2'>

# %%
print (k.values.shape[0])
# Out:
# 5

# %%
fig = plt.figure(figsize=(8,10))
img=plt.imread('construction.jpg')
for i in np.arange(k.values.shape[0]):
    ax = fig.add_subplot(k.values.shape[0],2, 2*(i + 1)-1,xticks=[],yticks=[])
    ax.imshow(img,cmap='gray')
    ax = fig.add_subplot(k.values.shape[0],2, 2*(i + 1))
    x=k.indices[i]
    y=k.values[i]
    ax.bar(x,y,align='center')
    ax.set_xlim (left=0)
    ax.set_ylim (bottom=0,top=1)
#    ax.set_xticks(np.arange(0,6))
    ax.set_yticks(np.arange(0,1.1,0.2))
    ax.set_xlabel('Class')
    ax.set_ylabel('Prob')
#plt.tight_layout()
plt.show()
